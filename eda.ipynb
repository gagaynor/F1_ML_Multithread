# %% [markdown]
# ### Inspect F1 data

# %%
import pandas as pd
import sqlite3
from sklearn import tree

# %%
# Connect to the SQLite database
conn = sqlite3.connect('F1_Prediction.db')

# Read the data from the database into pandas dataframes
race_results = pd.read_sql_query("SELECT * FROM RACE_RESULTS", conn)
circuits = pd.read_sql_query("SELECT DISTINCT CIRCUIT_NAME, CIRCUIT_TYPE FROM CIRCUITS", conn)

# %%
race_results.shape
# Out:
# (3220, 6)

# %%
race_results.head()
# Out:
#    PK        DRIVER             TEAM  POSITION             CIRCUIT  YEAR
# 0   1  M VERSTAPPEN  Red Bull Racing       1.0  Bahrain Grand Prix  2023
# 1   2       S PEREZ  Red Bull Racing       2.0  Bahrain Grand Prix  2023
# 2   3      F ALONSO     Aston Martin       3.0  Bahrain Grand Prix  2023
# 3   4       C SAINZ          Ferrari       4.0  Bahrain Grand Prix  2023
# 4   5    L HAMILTON         Mercedes       5.0  Bahrain Grand Prix  2023

# %%
circuits.head()
# Out:
#                CIRCUIT_NAME CIRCUIT_TYPE
# 0        Bahrain Grand Prix    Low-Speed
# 1  Saudi Arabian Grand Prix        Other
# 2     Australian Grand Prix        Other
# 3     Azerbaijan Grand Prix   High Speed
# 4          Miami Grand Prix       Street

# %%
circuits.shape
# Out:
# (21, 2)

# %%
# Merge the dataframes based on the circuit name
data = pd.merge(race_results, circuits, left_on='CIRCUIT', right_on='CIRCUIT_NAME')
data.head()
# Out:
#    PK        DRIVER             TEAM  POSITION             CIRCUIT  YEAR  \
# 0   1  M VERSTAPPEN  Red Bull Racing       1.0  Bahrain Grand Prix  2023
# 1   2       S PEREZ  Red Bull Racing       2.0  Bahrain Grand Prix  2023
# 2   3      F ALONSO     Aston Martin       3.0  Bahrain Grand Prix  2023
# 3   4       C SAINZ          Ferrari       4.0  Bahrain Grand Prix  2023
# 4   5    L HAMILTON         Mercedes       5.0  Bahrain Grand Prix  2023
#
#          CIRCUIT_NAME CIRCUIT_TYPE
# 0  Bahrain Grand Prix    Low-Speed
# 1  Bahrain Grand Prix    Low-Speed
# 2  Bahrain Grand Prix    Low-Speed
# 3  Bahrain Grand Prix    Low-Speed
# 4  Bahrain Grand Prix    Low-Speed

# %%
data.isnull().sum()
# Out:
# PK               0
# DRIVER           0
# TEAM             0
# POSITION        20
# CIRCUIT          0
# YEAR             0
# CIRCUIT_NAME     0
# CIRCUIT_TYPE     0
# dtype: int64

# %%
data[data['POSITION'].isna()]
# Out:
#         PK        DRIVER             TEAM  POSITION                 CIRCUIT  \
# 2780  1941     C LECLERC          Ferrari       NaN  Mexico City Grand Prix
# 2781  1942       C SAINZ          Ferrari       NaN  Mexico City Grand Prix
# 2782  1943  M VERSTAPPEN  Red Bull Racing       NaN  Mexico City Grand Prix
# 2783  1944   D RICCIARDO       AlphaTauri       NaN  Mexico City Grand Prix
# 2784  1945       S PEREZ  Red Bull Racing       NaN  Mexico City Grand Prix
# 2785  1946    L HAMILTON         Mercedes       NaN  Mexico City Grand Prix
# 2786  1947     O PIASTRI          McLaren       NaN  Mexico City Grand Prix
# 2787  1948     G RUSSELL         Mercedes       NaN  Mexico City Grand Prix
# 2788  1949      V BOTTAS       Alfa Romeo       NaN  Mexico City Grand Prix
# 2789  1950        G ZHOU       Alfa Romeo       NaN  Mexico City Grand Prix
# 2790  1951       P GASLY           Alpine       NaN  Mexico City Grand Prix
# 2791  1952  N HULKENBERG     Haas F1 Team       NaN  Mexico City Grand Prix
# 2792  1953      F ALONSO     Aston Martin       NaN  Mexico City Grand Prix
# 2793  1954       A ALBON         Williams       NaN  Mexico City Grand Prix
# 2794  1955        E OCON           Alpine       NaN  Mexico City Grand Prix
# 2795  1956   K MAGNUSSEN     Haas F1 Team       NaN  Mexico City Grand Prix
# 2796  1957      L NORRIS          McLaren       NaN  Mexico City Grand Prix
# 2797  1958     Y TSUNODA       AlphaTauri       NaN  Mexico City Grand Prix
# 2798  1959    L SARGEANT         Williams       NaN  Mexico City Grand Prix
# 2799  1960      L STROLL     Aston Martin       NaN  Mexico City Grand Prix
#
#       YEAR            CIRCUIT_NAME    CIRCUIT_TYPE
# 2780  2023  Mexico City Grand Prix  High-Elevation
# 2781  2023  Mexico City Grand Prix  High-Elevation
# 2782  2023  Mexico City Grand Prix  High-Elevation
# 2783  2023  Mexico City Grand Prix  High-Elevation
# 2784  2023  Mexico City Grand Prix  High-Elevation
# 2785  2023  Mexico City Grand Prix  High-Elevation
# 2786  2023  Mexico City Grand Prix  High-Elevation
# 2787  2023  Mexico City Grand Prix  High-Elevation
# 2788  2023  Mexico City Grand Prix  High-Elevation
# 2789  2023  Mexico City Grand Prix  High-Elevation
# 2790  2023  Mexico City Grand Prix  High-Elevation
# 2791  2023  Mexico City Grand Prix  High-Elevation
# 2792  2023  Mexico City Grand Prix  High-Elevation
# 2793  2023  Mexico City Grand Prix  High-Elevation
# 2794  2023  Mexico City Grand Prix  High-Elevation
# 2795  2023  Mexico City Grand Prix  High-Elevation
# 2796  2023  Mexico City Grand Prix  High-Elevation
# 2797  2023  Mexico City Grand Prix  High-Elevation
# 2798  2023  Mexico City Grand Prix  High-Elevation
# 2799  2023  Mexico City Grand Prix  High-Elevation

# %%
# Positions have not been filled in for Mexico City Grand Prix yet so drop from the dataset
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# PK              0
# DRIVER          0
# TEAM            0
# POSITION        0
# CIRCUIT         0
# YEAR            0
# CIRCUIT_NAME    0
# CIRCUIT_TYPE    0
# dtype: int64

# %%
# Preprocess your data if necessary, encoding categorical variables?
# Have not done any of this yet

# Define features and target variable
X = data[['DRIVER', 'TEAM', 'CIRCUIT_TYPE']]
y = data['POSITION']

# Convert categorical variables into numerical values using one-hot encoding
X = pd.get_dummies(X)

# %%
X
# Out:
#       DRIVER_A ALBON  DRIVER_A GIOVINAZZI  DRIVER_C LECLERC  DRIVER_C SAINZ  \
# 0              False                False             False           False
# 1              False                False             False           False
# 2              False                False             False           False
# 3              False                False             False            True
# 4              False                False             False           False
# ...              ...                  ...               ...             ...
# 3215           False                 True             False           False
# 3216           False                False             False           False
# 3217           False                False             False           False
# 3218           False                False             False           False
# 3219           False                False             False           False
#
#       DRIVER_D KVYAT  DRIVER_D RICCIARDO  DRIVER_E OCON  DRIVER_F ALONSO  \
# 0              False               False          False            False
# 1              False               False          False            False
# 2              False               False          False             True
# 3              False               False          False            False
# 4              False               False          False            False
# ...              ...                 ...            ...              ...
# 3215           False               False          False            False
# 3216           False               False          False            False
# 3217           False               False          False            False
# 3218           False               False          False            False
# 3219           False               False          False            False
#
#       DRIVER_G RUSSELL  DRIVER_G ZHOU  ...  TEAM_Red Bull Racing  \
# 0                False          False  ...                  True
# 1                False          False  ...                  True
# 2                False          False  ...                 False
# 3                False          False  ...                 False
# 4                False          False  ...                 False
# ...                ...            ...  ...                   ...
# 3215             False          False  ...                 False
# 3216             False          False  ...                 False
# 3217             False          False  ...                 False
# 3218             False          False  ...                 False
# 3219             False          False  ...                 False
#
#       TEAM_Renault  TEAM_Williams  TEAM_nan  CIRCUIT_TYPE_High Speed  \
# 0            False          False     False                    False
# 1            False          False     False                    False
# 2            False          False     False                    False
# 3            False          False     False                    False
# 4            False          False     False                    False
# ...            ...            ...       ...                      ...
# 3215         False          False     False                    False
# 3216         False           True     False                    False
# 3217         False          False     False                    False
# 3218         False          False     False                    False
# 3219         False          False     False                    False
#
#       CIRCUIT_TYPE_High-Elevation  CIRCUIT_TYPE_Intermediate  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ...                           ...                        ...
# 3215                        False                      False
# 3216                        False                      False
# 3217                        False                      False
# 3218                        False                      False
# 3219                        False                      False
#
#       CIRCUIT_TYPE_Low-Speed  CIRCUIT_TYPE_Other  CIRCUIT_TYPE_Street
# 0                       True               False                False
# 1                       True               False                False
# 2                       True               False                False
# 3                       True               False                False
# 4                       True               False                False
# ...                      ...                 ...                  ...
# 3215                    True               False                False
# 3216                    True               False                False
# 3217                    True               False                False
# 3218                    True               False                False
# 3219                    True               False                False
#
# [3200 rows x 53 columns]

# %%
# Change n_jobs to modify how many CPU's are being utilized
model = tree.DecisionTreeClassifier()

# Fit the model to your data
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# mark a 1 for the values we would like to predict, refer to the table to know which circuit type to use. 
# for example Albon = 1, Williams = 1 and Street type circuit = 1 for las vegas. Alex Albon would be projected 14th.
upcoming_race_df = pd.DataFrame({
    'DRIVER_A ALBON': [1], 'DRIVER_A GIOVINAZZI': [0],
    'DRIVER_C LECLERC': [0], 'DRIVER_C SAINZ': [0], 'DRIVER_D KVYAT': [0],
    'DRIVER_D RICCIARDO': [0], 'DRIVER_E OCON': [0], 'DRIVER_F ALONSO': [0],
    'DRIVER_G RUSSELL': [0], 'DRIVER_G ZHOU': [0], 'DRIVER_K MAGNUSSEN': [0],
    'DRIVER_K RAIKKONEN': [0],'DRIVER_L HAMILTON': [0], 'DRIVER_L LAWSON': [0], 'DRIVER_L NORRIS': [0],
    'DRIVER_L SARGEANT': [0], 'DRIVER_L STROLL': [0], 'DRIVER_M SCHUMACHER': [0],
    'DRIVER_M VERSTAPPEN': [0], 'DRIVER_N DE VRIES': [0], 'DRIVER_N HULKENBERG': [0],
    'DRIVER_N LATIFI': [0], 'DRIVER_N MAZEPIN': [0], 'DRIVER_O PIASTRI': [0],
    'DRIVER_P FITTIPALDI': [0], 'DRIVER_P GASLY': [0], 'DRIVER_R GROSJEAN': [0],
    'DRIVER_R KUBICA': [0], 'DRIVER_S PEREZ': [0], 'DRIVER_S VETTEL': [0],
    'DRIVER_V BOTTAS': [0],'DRIVER_Y TSUNODA': [0], 'DRIVER_nan': [0],
    'TEAM_Alfa Romeo': [0], 'TEAM_Alfa Romeo Racing': [0], 'TEAM_AlphaTauri':[1],
    'TEAM_Alpine':[0], 'TEAM_Aston Martin': [0], 'TEAM_Ferrari': [0], 'TEAM_Haas F1 Team': [0],
    'TEAM_McLaren': [0], 'TEAM_Mercedes': [0], 'TEAM_Racing Point': [0], 'TEAM_Red Bull Racing': [1], 
    'TEAM_Renault': [0], 'TEAM_Williams': [1], 'TEAM_nan': [0],
    'CIRCUIT_TYPE_High Speed': [0], 'CIRCUIT_TYPE_High-Elevation': [0],
    'CIRCUIT_TYPE_Intermediate': [0], 'CIRCUIT_TYPE_Low-Speed': [0],
    'CIRCUIT_TYPE_Other': [0], 'CIRCUIT_TYPE_Street': [1]
})

# Make predictions using the trained model
predicted_positions = model.predict(upcoming_race_df)

# Print the predicted positions for the upcoming race
print("Predicted positions for the upcoming race in Las Vegas:")
print(predicted_positions)
# Out:
# Predicted positions for the upcoming race in Las Vegas:
# [14.]
